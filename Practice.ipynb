# %% [markdown]
# <a href="https://colab.research.google.com/github/RitikaDharamkarJ/Testing/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# %pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# sample_data/

# %%
# %cd sample_data/
# %ls
# Out:
# /content/sample_data
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
data_frame = pd.read_csv('/content/log2.csv', encoding= 'utf-8')

# %%
data_frame
# Out:
#        Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# 0            57222                53            54587                    53
# 1            56258              3389            56258                  3389
# 2             6881             50321            43265                 50321
# 3            50553              3389            50553                  3389
# 4            50002               443            45848                   443
# ...            ...               ...              ...                   ...
# 65527        63691                80            13237                    80
# 65528        50964                80            13485                    80
# 65529        54871               445                0                     0
# 65530        54870               445                0                     0
# 65531        54867               445                0                     0
#
# ...

# %%
data_frame.dtypes
# Out:
# Source Port              int64
# Destination Port         int64
# NAT Source Port          int64
# NAT Destination Port     int64
# Action                  object
# Bytes                    int64
# Bytes Sent               int64
# Bytes Received           int64
# Packets                  int64
# Elapsed Time (sec)       int64
# pkts_sent                int64
# pkts_received            int64
# dtype: object

# %%
data_frame.describe()
# Out:
#         Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# count  65532.000000      65532.000000     65532.000000          65532.000000
# mean   49391.969343      10577.385812     19282.972761           2671.049930
# std    15255.712537      18466.027039     21970.689669           9739.162278
# min        0.000000          0.000000         0.000000              0.000000
# 25%    49183.000000         80.000000         0.000000              0.000000
# 50%    53776.500000        445.000000      8820.500000             53.000000
# 75%    58638.000000      15000.000000     38366.250000            443.000000
# max    65534.000000      65535.000000     65535.000000          65535.000000
#
#               Bytes    Bytes Sent  Bytes Received       Packets  \
# count  6.553200e+04  6.553200e+04    6.553200e+04  6.553200e+04
# mean   9.712395e+04  2.238580e+04    7.473815e+04  1.028660e+02
# std    5.618439e+06  3.828139e+06    2.463208e+06  5.133002e+03
# ...

# %%
data_frame_with_no_source_port = data_frame.drop("Source Port", axis = 1)

# %%
data_frame_with_no_source_port.describe()
# Out:
#        Destination Port  NAT Source Port  NAT Destination Port         Bytes  \
# count      65532.000000     65532.000000          65532.000000  6.553200e+04
# mean       10577.385812     19282.972761           2671.049930  9.712395e+04
# std        18466.027039     21970.689669           9739.162278  5.618439e+06
# min            0.000000         0.000000              0.000000  6.000000e+01
# 25%           80.000000         0.000000              0.000000  6.600000e+01
# 50%          445.000000      8820.500000             53.000000  1.680000e+02
# 75%        15000.000000     38366.250000            443.000000  7.522500e+02
# max        65535.000000     65535.000000          65535.000000  1.269359e+09
#
#          Bytes Sent  Bytes Received       Packets  Elapsed Time (sec)  \
# count  6.553200e+04    6.553200e+04  6.553200e+04        65532.000000
# mean   2.238580e+04    7.473815e+04  1.028660e+02           65.833577
# ...

# %%
my_final_df = data_frame_with_no_source_port.rename(columns = {"Elapsed Time (sec)": "elapsed_time"})

# %%
my_final_df.describe()
# Out:
#        Destination Port  NAT Source Port  NAT Destination Port         Bytes  \
# count      65532.000000     65532.000000          65532.000000  6.553200e+04
# mean       10577.385812     19282.972761           2671.049930  9.712395e+04
# std        18466.027039     21970.689669           9739.162278  5.618439e+06
# min            0.000000         0.000000              0.000000  6.000000e+01
# 25%           80.000000         0.000000              0.000000  6.600000e+01
# 50%          445.000000      8820.500000             53.000000  1.680000e+02
# 75%        15000.000000     38366.250000            443.000000  7.522500e+02
# max        65535.000000     65535.000000          65535.000000  1.269359e+09
#
#          Bytes Sent  Bytes Received       Packets  elapsed_time  \
# count  6.553200e+04    6.553200e+04  6.553200e+04  65532.000000
# mean   2.238580e+04    7.473815e+04  1.028660e+02     65.833577
# std    3.828139e+06    2.463208e+06  5.133002e+03    302.461762
# ...
